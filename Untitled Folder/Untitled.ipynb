# %%
from nba_api.stats.static import teams
from nba_api.stats.endpoints import leaguegamefinder
import pandas as pd

nba_teams = teams.get_teams()
# Select the dictionary for the Celtics, which contains their team ID
celtics = [team for team in nba_teams if team['abbreviation'] == 'BOS'][0]
celtics_id = celtics['id']

# %%
'''Query for games where the Celtics were playing
gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=celtics_id)
The first DataFrame of those returned is what we want.
games = gamefinder.get_data_frames()[1]
games.head()'''

# %%
# Get **all** the games so we can filter to an individual GAME_ID
result = leaguegamefinder.LeagueGameFinder()
all_games = result.get_data_frames()[0]

# %%
df = pd.DataFrame(all_games)

# %%
df
# Out:
#       SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME  \
# 0         12019  1610612746               LAC            LA Clippers
# 1         12019  1610612754               IND         Indiana Pacers
# 2         12019  1610612745               HOU        Houston Rockets
# 3         12019  1610612758               SAC       Sacramento Kings
# 4         42019  1611661323               CON        Connecticut Sun
# ...         ...         ...               ...                    ...
# 29995     22012  1610612754               IND         Indiana Pacers
# 29996     22012  1610612761               TOR        Toronto Raptors
# 29997     22012  1610612766               CHA      Charlotte Bobcats
# 29998     22012  1610612744               GSW  Golden State Warriors
# 29999     22012  1610612751               BKN          Brooklyn Nets
#
#           GAME_ID   GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  \
# 0      0011900002  2019-10-04  LAC vs. HOU  L  239   96  ...   0.600    11
# 1      0011900003  2019-10-04    IND @ SAC  W  264  132  ...   0.788    14
# 2      0011900002  2019-10-04    HOU @ LAC  W  239  109  ...   0.800    12
# 3      0011900003  2019-10-04  SAC vs. IND  L  264  131  ...   0.778     6
# 4      1041900402  2019-10-01    CON @ WAS  W  200   99  ...   0.778    17
# ...           ...         ...          ... ..  ...  ...  ...     ...   ...
# 29995  0021201064  2013-03-27    IND @ HOU  W  240  100  ...   0.857     9
# 29996  0021201057  2013-03-27  TOR vs. ATL  L  239   88  ...   0.700    10
# 29997  0021201059  2013-03-27  CHA vs. ORL  W  238  114  ...   0.714    11
# 29998  0021201069  2013-03-27  GSW vs. SAC  L  241   98  ...   0.846    13
# 29999  0021201070  2013-03-27    BKN @ POR  W  240  111  ...   0.560    19
#
#        DREB  REB  AST  STL  BLK  TOV  PF  PLUS_MINUS
# 0        38   49   26    5    8   22  35       -13.0
# 1        33   47   26   11    3   24  29         1.0
# 2        40   52   21   11    5   20  29        13.0
# 3        24   30   30    8    4   22  31        -1.0
# 4        24   41   20    3    3    9  12        12.0
# ...     ...  ...  ...  ...  ...  ...  ..         ...
# 29995    36   45   20    9    5   12  21         9.0
# 29996    32   42   20    8    1   19  18       -19.0
# 29997    32   43   26    5    8   10  12         6.0
# 29998    28   41   30    9    4   14  19        -7.0
# 29999    35   54   24    8    1    9  20        18.0
#
# [30000 rows x 28 columns]

# %%
# Out:
# array(['0011900002', '0011900003', '1041900402', ..., '0021201064',
#        '0021201069', '0021201070'], dtype=object)
