# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Importando a base de dados
df = pd.read_csv("nba.games.stats.csv")

# %%
# Out:
#    Unnamed: 0 Team  Game        Date  Home Opponent WINorLOSS  TeamPoints  \
# 0           1  ATL     1  2014-10-29  Away      TOR         L         102
# 1           2  ATL     2  2014-11-01  Home      IND         W         102
# 2           3  ATL     3  2014-11-05  Away      SAS         L          92
# 3           4  ATL     4  2014-11-07  Away      CHO         L         119
# 4           5  ATL     5  2014-11-08  Home      NYK         W         103
#
#    OpponentPoints  FieldGoals  ...  Opp.FreeThrows  Opp.FreeThrowsAttempted  \
# 0             109          40  ...              27                       33
# 1              92          35  ...              18                       21
# 2              94          38  ...              27                       38
# 3             122          43  ...              20                       27
# 4              96          33  ...               8                       11
#
# ...

# %%
# Selecionando o que me interessa da base
df.columns
# Out:
# Index(['Unnamed: 0', 'Team', 'Game', 'Date', 'Home', 'Opponent', 'WINorLOSS',
#        'TeamPoints', 'OpponentPoints', 'FieldGoals', 'FieldGoalsAttempted',
#        'FieldGoals.', 'X3PointShots', 'X3PointShotsAttempted', 'X3PointShots.',
#        'FreeThrows', 'FreeThrowsAttempted', 'FreeThrows.', 'OffRebounds',
#        'TotalRebounds', 'Assists', 'Steals', 'Blocks', 'Turnovers',
#        'TotalFouls', 'Opp.FieldGoals', 'Opp.FieldGoalsAttempted',
#        'Opp.FieldGoals.', 'Opp.3PointShots', 'Opp.3PointShotsAttempted',
#        'Opp.3PointShots.', 'Opp.FreeThrows', 'Opp.FreeThrowsAttempted',
#        'Opp.FreeThrows.', 'Opp.OffRebounds', 'Opp.TotalRebounds',
#        'Opp.Assists', 'Opp.Steals', 'Opp.Blocks', 'Opp.Turnovers',
#        'Opp.TotalFouls'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0', 'Team', 'Game', 'Date', 'Home', 'Opponent'], axis=1, inplace=True)

# %%
#Transformando os dados categóricos de FTR para numeros
from sklearn.preprocessing import LabelEncoder
# Create a label (category) encoder object
le = LabelEncoder()
# Fit the encoder to the pandas column
le.fit(df['WINorLOSS'])
# Apply the fitted encoder to the pandas column
df['WINorLOSS'] = le.transform(df['WINorLOSS'])

# %%
#normalizando os dados
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(fut.drop('WINorLOSS',axis=1))
#fut_normalizado =#normalizando os dados
from sklearn.preprocessing import StandardScaler scaler.transform(df.drop('WINorLOSS',axis=1))
df_param = pd.DataFrame(df_normalizado, columns=df.columns[1:])
df_param.head()
# Out:
#   File "<ipython-input-13-6885f0b72e1d>", line 4
#     from sklearn.preprocessing import StandardScaler scaler.transform(df.drop('WINorLOSS',axis=1))
#                                                           ^
# SyntaxError: invalid syntax
